# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def helper(self,add):
    self.add=add
    for i in range(self.helpfer.val):
        self.add+=i

# %%
pd.read_csv('movies.csv')
pd.head()
pd.describe()
